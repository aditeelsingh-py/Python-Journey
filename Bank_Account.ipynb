# %% [markdown]
# <a href="https://colab.research.google.com/github/aditeelsingh-py/Python-Journey/blob/main/Bank_Account.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Person:
  TotalCustomers=0
  TotalBalance=0
  def __init__(self,name,age,phone):
    self.name=name
    self.age=age
    self.phone=phone
    self.balance=0
  def OpenAccount(self):
    if self.name not in person:
      person.append(self.name)
      print("Account opened successfully")
      Person.TotalCustomers+=1
    else:
      print("Account already exists")
  def Deposit(self,amount):
    self.balance+=amount
    print("account deposited successfully")
    Person.TotalBalance+=amount
  def Withdraw(self,amount):
    if amount>self.balance:
      print("Insufficient balance")
    else:
      self.balance-=amount
      print("Withdrawal successful")
      Person.TotalBalance-=amount
  def Transfer(self,amount,OtherPerson):
    if amount>self.balance:
      print("Insufficient balance")
    else:
      self.balance-=amount
      OtherPerson.balance+=amount
      print("Transfer successful")
  def CheckBalance(self):
    return self.balance
  def MiniStatement(self):
    print("Mini statement")
    print("Name:", self.name)
    print("Age:", self.age)
    print("Phone:", self.phone)
    print("Balance:", self.balance)
  def CustomerDetails(self):
    print("Customer Details")
    print("Name:", self.name)
    print("Age:", self.age)
    print("Phone:", self.phone)
    print("Balance:", self.balance)
  def BankReport(self):
    print("Bank Report")
    print("Total Customers",Person.TotalCustomers)
    print("Total Balance", Person.TotalBalance)
p1=Person("John",30,"1234567890")
p1.OpenAccount()
Person.TotalCustomers+=1
p1.Deposit(1000)
Person.TotalBalance+=1000

# %%
while True:
  print("1. Open Account")
  print("2. Deposit")
  print("3. Withdraw")
  print("4. Transfer")
  print("5. Check Balance")
  print("6. Mini Statement")
  print("7. Customer Details")
  print("8. Bank Report")
  print("9. Exit")

  choice=int(input("enter choice"))
# Out:
# 1. Open Account
# 2. Deposit
# 3. Withdraw
# 4. Transfer
# 5. Check Balance
# 6. Mini Statement
# 7. Customer Details
# 8. Bank Report
# 9. Exit
# 1. Open Account
# 2. Deposit
# 3. Withdraw
# 4. Transfer
# 5. Check Balance
# 6. Mini Statement
# 7. Customer Details
# 8. Bank Report
# 9. Exit
